# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
# Have Pandas read from clipboard!

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First', 'NFL',
#        'season', 'Division'],
#       dtype='object')

# %%
nfl_frame['Team']
# Out:
# 0       Green Bay Packers
# 1          Dallas Cowboys
# 2    New England Patriots
# 3           Chicago Bears
# 4        Baltimore Ravens
# Name: Team, dtype: object

# %%
DataFrame(nfl_frame, columns = ['Team', 'Division', 'GP'])
# Out:
#                    Team   Division     GP
# 0     Green Bay Packers  NFC North  1,401
# 1        Dallas Cowboys   NFC East    947
# 2  New England Patriots   AFC East    949
# 3         Chicago Bears  NFC North  1,435
# 4      Baltimore Ravens  AFC North    417

# %%
DataFrame(nfl_frame, columns = ['Team', 'season', 'GP', 'Stadium']) # Try a column that doesnt exist
# Out:
#                    Team  season     GP  Stadium
# 0     Green Bay Packers     NaN  1,401      NaN
# 1        Dallas Cowboys     NaN    947      NaN
# 2  New England Patriots     NaN    949      NaN
# 3         Chicago Bears     NaN  1,435      NaN
# 4      Baltimore Ravens     NaN    417      NaN

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
nfl_frame.head(2) # .head() default is 5 ---- .tail() to grab last rows
# Out:
#    Rank               Team     GP  Won  Lost  Tied   Pct.  First NFL season  \
# 0     1  Green Bay Packers  1,401  782   581    38  0.572              1921
# 1     2     Dallas Cowboys    947  538   403     6  0.571              1960
#
#     Division
# 0  NFC North
# 1   NFC East

# %%
# nfl_frame.ix[3]

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division         Stadium
# 0              1921  NFC North  Levi's Stadium
# 1              1960   NFC East  Levi's Stadium
# 2              1960   AFC East  Levi's Stadium
# 3              1920  NFC North  Levi's Stadium
# 4              1996  AFC North  Levi's Stadium

# %%
nfl_frame['Stadium'] = np.arange(5)

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division  Stadium
# 0              1921  NFC North        0
# 1              1960   NFC East        1
# 2              1960   AFC East        2
# 3              1920  NFC North        3
# 4              1996  AFC North        4

# %%
stadiums = Series(["AT&T Stadium", "Gillette"], index=[4,0])

# %%
stadiums
# Out:
# 4    AT&T Stadium
# 0        Gillette
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division       Stadium
# 0              1921  NFC North      Gillette
# 1              1960   NFC East           NaN
# 2              1960   AFC East           NaN
# 3              1920  NFC North           NaN
# 4              1996  AFC North  AT&T Stadium

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
data = {'City': ['SF', 'LA', 'NYC'], 'Population':[837000, 3880000, 840000]}

# %%
data
# Out:
# {'City': ['SF', 'LA', 'NYC'], 'Population': [837000, 3880000, 840000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC      840000
